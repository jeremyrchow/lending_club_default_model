# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt
import seaborn as sns
import patsy
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import pickle
# Import models
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from joblib import dump,load
from sklearn.preprocessing import StandardScaler
# Import scoring metrics
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import precision_score, recall_score, precision_recall_curve,f1_score, fbeta_score
# %matplotlib inline
pd.set_option('display.max_columns', None)
np.set_printoptions(suppress=True) # Suppress scientific notation where possible

# %%
# Columns from kaggle dataset for reference
old_col= '''Index(['Loan ID', 'Customer ID', 'Loan Status', 'Current Loan Amount', 'Term',
       'Credit Score', 'Annual Income', 'Years in current job',
       'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
       'Months since last delinquent', 'Number of Open Accounts',
       'Number of Credit Problems', 'Current Credit Balance',
       'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
      dtype='object')'''

# %% [markdown]
# # Read in CSV

# %%
#df = pd.read_csv('~/Downloads/LoanStats3c.csv',header = 1)
#df.to_pickle('./data/loan_data_2014.zip',compression = 'zip')

# %% [markdown]
# # Drop unnecessary columns:

# %%
df = pd.read_pickle('./data/loan_data_2014.zip',compression = 'zip')
df.shape
# Out:
# (235631, 145)

# %%
# Only take rows of loans that are charged off or fully paid as results
df = df.loc[(df['loan_status'] == 'Fully Paid') | (df['loan_status'] == 'Charged Off')]

# %%
df=df.drop(columns = [
        # Only looking at loans for individuals, not joint
        'annual_inc_joint',
        'application_type',
        'dti_joint',
        'verification_status_joint',
        'revol_bal_joint', 

        # Don't need specific ID info
        'id',
        'member_id',
    
        # Only care about information available pre loan
        'collection_recovery_fee',
        'collections_12_mths_ex_med',
        'delinq_amnt',
        'last_credit_pull_d',
        'last_pymnt_amnt',
        'last_pymnt_d',
        'next_pymnt_d',
        'pymnt_plan',
        'total_pymnt',
        'total_pymnt_inv',
        'total_rec_int',
        'total_rec_late_fee',
        'total_rec_prncp',
        # Hard to classify, may use regex text processing in future
        'emp_title',
    
        # hardship info is post issuing
        'hardship_flag',
        'hardship_status',
        'hardship_type',
        'hardship_reason',
        'deferral_term',
        'hardship_amount',
        'hardship_start_date',
        'hardship_end_date',
        'payment_plan_start_date',
        'hardship_length',
        'hardship_dpd',
        'hardship_loan_status',
        'orig_projected_additional_accrued_interest',
        'hardship_payoff_balance_amount',
        'hardship_last_payment_amount',
    

        # Trying to extrapolate beyond certain issuing dates of loans
        'issue_d',
        'mths_since_last_major_derog',
        'mths_since_last_record',
        'mths_since_recent_inq',
        'num_tl_30dpd',
        'num_tl_120dpd_2m',
        
        'debt_settlement_flag',
        'debt_settlement_flag_date',
        'desc',
    
        # sub_grade category already contains grade
        'grade',
    
        # This is for investors / loan funding
        'initial_list_status',
        'funded_amnt',
        'funded_amnt_inv',              
        # Probably useful metrics, but all NaN in this dataset              
        'open_acc_6m',                 
        'open_il_12m',
        'open_il_24m',                     
        'open_act_il',   
        'open_rv_12m',
        'open_rv_24m',
                      
        'out_prncp', 
        'out_prncp_inv',
        'policy_code',
        'recoveries',
        # Columns related to debt settlement; we only care about pre loan features              
        'settlement_status',
        'settlement_date',
        'settlement_amount',
        'settlement_percentage',
        'settlement_term',
        # Only looking for one applicant 
        #'sec_app_fico_range_low', 
        #'sec_app_fico_range_high', 
        'sec_app_earliest_cr_line', 
        'sec_app_inq_last_6mths', 
        'sec_app_mort_acc', 
        'sec_app_open_acc', 
        'sec_app_revol_util',
        'sec_app_open_act_il',
        'sec_app_num_rev_accts',
        'sec_app_chargeoff_within_12_mths',
        'sec_app_collections_12_mths_ex_med', 
        'sec_app_mths_since_last_major_derog', 
        'title',
        'total_cu_tl',
                      
        'url', 
        # May be good to look at later
        'zip_code'])

print('Before dropping NaN\'s: ',df.shape)
df.dropna(how='all', inplace = True)
print('After dropping NaN Rows: ',df.shape)
pre_drop_col = df.columns
df.dropna(axis=1, how='all',inplace = True)
print('After dropping NaN Columns: ',df.shape)
post_drop_col = df.columns
# Out:
# Before dropping NaN's:  (223102, 67)
# After dropping NaN Rows:  (223102, 67)
# After dropping NaN Columns:  (223102, 60)

# %%
dropped_nan_columns = set(pre_drop_col) - set(post_drop_col)
print("Dropped NaN Columns: ", dropped_nan_columns)
# Out:
# Dropped NaN Columns:  {'mths_since_rcnt_il', 'all_util', 'inq_last_12m', 'il_util', 'total_bal_il', 'max_bal_bc', 'inq_fi'}

# %%
plt.figure(figsize=(24, 24))
sns.heatmap(df.corr(),vmin = -1, vmax = 1, cmap = 'seismic',annot = True)

# %%
df.sample(5)
# Out:
#         loan_amnt        term int_rate  installment sub_grade emp_length  \
# 186471    14400.0   36 months   11.99%       478.22        B3  10+ years
# 40472      8000.0   36 months    6.03%       243.49        A1  10+ years
# 165730     2350.0   36 months   16.59%        83.31        D1    7 years
# 28031     10000.0   36 months    7.49%       311.02        A4    9 years
# 148457    17600.0   60 months   17.57%       442.82        D4    6 years
#
#        home_ownership  annual_inc verification_status  loan_status  \
# 186471       MORTGAGE     70000.0     Source Verified   Fully Paid
# 40472             OWN     43000.0     Source Verified   Fully Paid
# 165730           RENT     12000.0            Verified  Charged Off
# 28031            RENT     29000.0     Source Verified   Fully Paid
# 148457       MORTGAGE     70000.0     Source Verified   Fully Paid
#
#                    purpose addr_state    dti  delinq_2yrs earliest_cr_line  \
# 186471         credit_card         NC  12.31          0.0         Jun-1983
# 40472             vacation         CT  18.20          0.0         May-1988
# 165730  debt_consolidation         IL  29.70          0.0         Dec-2008
# 28031          credit_card         UT  33.17          0.0         Jul-1999
# 148457    home_improvement         AK  12.41          0.0         Jun-2010
#
#         inq_last_6mths  mths_since_last_delinq  open_acc  pub_rec  revol_bal  \
# 186471             3.0                     NaN       9.0      1.0     3355.0
# 40472              1.0                     NaN      20.0      0.0    31651.0
# 165730             0.0                     NaN       3.0      0.0      359.0
# 28031              0.0                     NaN      19.0      0.0    25461.0
# 148457             1.0                     NaN      12.0      0.0     9680.0
#
#        revol_util  total_acc  acc_now_delinq  tot_coll_amt  tot_cur_bal  \
# 186471        39%       17.0             0.0         100.0      37817.0
# 40472       26.2%       41.0             0.0           0.0     152019.0
# 165730        11%        6.0             0.0           0.0       5831.0
# 28031       54.6%       23.0             0.0           0.0      25461.0
# 148457      36.9%       13.0             0.0           0.0     224627.0
#
#         total_rev_hi_lim  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  \
# 186471            8600.0                   3.0       5402.0          5245.0
# 40472           120800.0                   6.0       7601.0         74519.0
# 165730            3400.0                   2.0       1943.0           400.0
# 28031            46600.0                   2.0       1340.0          9974.0
# 148457           26200.0                   9.0      18719.0          6727.0
#
#         bc_util  chargeoff_within_12_mths  mo_sin_old_il_acct  \
# 186471     39.0                       0.0               128.0
# 40472      12.2                       0.0               126.0
# 165730     90.0                       0.0                64.0
# 28031      55.5                       0.0               118.0
# 148457     45.7                       0.0                26.0
#
#         mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  \
# 186471                 369.0                   11.0             4.0       0.0
# 40472                  317.0                    8.0             8.0       1.0
# 165730                  33.0                   13.0            13.0       0.0
# 28031                  184.0                   12.0            12.0       0.0
# 148457                  47.0                    2.0             2.0       1.0
#
#         mths_since_recent_bc  mths_since_recent_bc_dlq  \
# 186471                  11.0                       NaN
# 40472                    8.0                       NaN
# 165730                  13.0                       NaN
# 28031                   12.0                       NaN
# 148457                   2.0                       NaN
#
#         mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 186471                             NaN                    0.0             4.0
# 40472                              NaN                    0.0             4.0
# 165730                             NaN                    0.0             1.0
# 28031                              NaN                    0.0            11.0
# 148457                             NaN                    0.0             3.0
#
#         num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 186471              4.0          6.0        7.0        3.0            7.0
# 40472               7.0         12.0       23.0        9.0           17.0
# 165730              2.0          1.0        1.0        4.0            2.0
# 28031              17.0         12.0       12.0        2.0           19.0
# 148457              6.0          5.0        6.0        2.0            9.0
#
#         num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_90g_dpd_24m  \
# 186471           14.0                  4.0       9.0                 0.0
# 40472            31.0                  7.0      20.0                 0.0
# 165730            2.0                  1.0       3.0                 0.0
# 28031            21.0                 17.0      19.0                 0.0
# 148457           10.0                  6.0      12.0                 0.0
#
#         num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  \
# 186471                 2.0           100.0              20.0
# 40472                  3.0           100.0               8.3
# 165730                 0.0           100.0             100.0
# 28031                  1.0           100.0              16.7
# 148457                 4.0           100.0              20.0
#
#         pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  total_bal_ex_mort  \
# 186471                   1.0        0.0          52844.0            37817.0
# 40472                    0.0        0.0         260034.0            44619.0
# 165730                   0.0        0.0          10750.0             5831.0
# 28031                    0.0        0.0          46600.0            25461.0
# 148457                   0.0        0.0         257267.0            30122.0
#
#         total_bc_limit  total_il_high_credit_limit disbursement_method
# 186471          8600.0                     44244.0                Cash
# 40472          84900.0                     21234.0                Cash
# 165730           400.0                      7350.0                Cash
# 28031          22400.0                         0.0                Cash
# 148457         12400.0                     27934.0                Cash

# %%
# df[['int_rate','grade','sub_grade']].sort_values(by = 'int_rate')

# %% [markdown]
# # Clean Columns

# %%
def drop_percentage_signs(df, column_name):
    new_column_name = column_name + '_percent'
    df[new_column_name] = df[column_name].astype(str).str[:-1].astype(np.float64)
    return df.drop(columns = [column_name])

# %%
df.shape
# Out:
# (223102, 60)

# %%
# Clean columns
# Convert loan terms into two categories 'short' and 'long'
df['term'] = df['term'].str.replace('36 months','short').str.replace('60 months','long').str.strip()

# Convert interest rate from percentage to float
df['int_rate'].dropna(axis = 0,how = 'any', inplace = True)
df=drop_percentage_signs(df,'int_rate')


# Fill Na's with 0.0% in revolving balance (unused revolving balance counts as NaN)
df['revol_util'].fillna(value = '0.0%',inplace = True)
df=drop_percentage_signs(df, 'revol_util')

# %%
df.shape
# Out:
# (223102, 60)

# %% [markdown]
# # Categorize 'Months Since' Variables
#
# - First do a pd.cut() to bin the data into categories.
# - Then fill nans as another category
# - patsy.dmatrix does 'treatment' to do onehot encoding automatically on string columns

# %%
df['mths_since_last_delinq'] = \
pd.cut(df['mths_since_last_delinq'],5,labels =
       ['0-3 years','3-6 years','6-9 years','9-12 years','12-15 years'
       ]).cat.add_categories('never').fillna('never') # 

df['mths_since_recent_bc'] = \
pd.cut(df['mths_since_recent_bc'],5,labels =
       ['0-10 years','10-20 years','20-30 years','30-40 years','40-50 years']
      ).cat.add_categories('never').fillna('never')# 

df['mths_since_recent_bc_dlq'] = \
pd.cut(df['mths_since_recent_bc_dlq'],5, labels = 
      ['0-3 years','3-6 years','6-9 years','9-12 years','12-15 years'
       ]).cat.add_categories('never').fillna('never') # 

df['mths_since_recent_revol_delinq'] = \
pd.cut(df['mths_since_recent_revol_delinq'],5, labels = 
      ['0-3 years','3-6 years','6-9 years','9-12 years','12-15 years'
       ]).cat.add_categories('never').fillna('never') # 
df['mo_sin_old_il_acct'] = \
pd.cut(df['mo_sin_old_il_acct'],5).cat.add_categories('never').fillna('never')

# %%
def add_days_since_col(df,column_name):
    new_col_name = 'days_since_' + column_name
    df[new_col_name] = df[column_name].apply(lambda x: (dt.datetime.today().date() - 
                                                      dt.datetime.strptime(x,'%b-%Y').date()).days)
    return df.drop(columns = [column_name])

df = add_days_since_col(df,'earliest_cr_line')

# Last credit pulled has data leakage because credit is constantly pulled for non-defaulted loans. 
#df= df.dropna(subset = ['last_credit_pull_d'])
#df = add_days_since_col(df,'last_credit_pull_d')

# %% [markdown]
# # Patsy.dmatrix (pass string like last project, but no y~)

# %%
df.shape
# Out:
# (223102, 60)

# %%
# What NA Columns are we dropping
df.isnull().sum()[df.isnull().sum() != 0]
df_temp = df.dropna()

# Convert target to binary,
df_temp['loan_status'] = df_temp['loan_status'].replace({'Fully Paid': 0, 'Charged Off': 1}).astype(int)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# # Modeling

# %%
# Define a 'basic' dataframe that only predicts off LendingClub sub_grade feature
df_basic= df_temp[['loan_status','sub_grade']]
df_basic.shape
# Out:
# (209163, 2)

# %%
# Select a grade to look at 

# Only look at low grades, high interest
#df_temp = df_temp.loc[df_temp['sub_grade'].apply(lambda element: ('B' in element))]

df_temp.drop(columns = 'sub_grade', inplace = True)
# df_temp = df_temp.loc[df_temp['sub_grade'].apply(lambda element: ('D' in element) | ('E' in element))]

# Only look at good grades, low interest
# df_temp = df_temp.loc[df_temp['sub_grade'].apply(lambda element: ('A' in element) |
#                                                  ('B' in element) |
#                                                  ('C' in element))]

#Percentage of target
sum(df_temp['loan_status'] == '`')/df_temp.shape[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-144-4a10046ab996> in <module>
#       4 #df_temp = df_temp.loc[df_temp['sub_grade'].apply(lambda element: ('B' in element))]
#       5
# ----> 6 df_temp.drop(columns = 'sub_grade', inplace = True)
#       7 # df_temp = df_temp.loc[df_temp['sub_grade'].apply(lambda element: ('D' in element) | ('E' in element))]
#       8
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# -> 3780                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3781
#    3782         if inplace:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3810                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3811             else:
# -> 3812                 new_axis = axis.drop(labels, errors=errors)
#    3813             result = self.reindex(**{axis_name: new_axis})
#    3814
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    4963             if errors != 'ignore':
#    4964                 raise KeyError(
# -> 4965                     '{} not found in axis'.format(labels[mask]))
#    4966             indexer = indexer[~mask]
#    4967         return self.delete(indexer)
#
# KeyError: "['sub_grade'] not found in axis"

# %%
len(df_temp.columns)
# Out:
# 59

# %%
df_temp.shape
# Out:
# (209163, 59)

# %%
#plt.figure(figsize=(24, 24))
#sns.heatmap(df_temp.corr(),vmin = -1, vmax = 1, cmap = 'seismic',annot = True)

# %%
def patsy_string_from_df(df):
    """Makes patsy string from dataframe df. Drops 'loan_status' variable by default."""
    df = df.drop(columns = ['loan_status']) # Drop the target variable, in this case it's loan_status
    patsy_string = ''
    for title in df.columns:
        patsy_string += title + " + "
    #remove last plus and spaces from string
    patsy_string=patsy_string[:-3]
    # print("Patsy String: " +patsy_string)
    return patsy_string

# %%
# Make patsy design matrix from all dataframe 
# This takes care of onehot variables
X = patsy.dmatrix(patsy_string_from_df(df_temp),df_temp)
y = df_temp['loan_status'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123456)
# Standardize for models that nead standardization variables
scaler = StandardScaler()
scaler.fit(X_train)
X_train_standard = scaler.transform(X_train)
X_test_standard = scaler.transform(X_test)

# Standardize all for simplicity
X_train = X_train_standard
X_test = X_test_standard

# %%
Xb = patsy.dmatrix(patsy_string_from_df(df_basic),df_basic)
yb = df_basic['loan_status'].values
Xb_train, Xb_test, yb_train, yb_test = train_test_split(Xb, yb, test_size=0.2, random_state=123456)

# %% [markdown]
# # Models Tried

# %% [markdown]
# ## Gridsearch for RandomForest

# %%
# from sklearn.utils import parallel_backend as pb
# param_grid = {
# #    'max_depth': [70, 90],
# #    'max_features': ['sqrt'],
# #    'min_samples_leaf': [1, 2],
# #    'min_samples_split': [2, 3],
#     'n_estimators': [200, 400]
# }

# with pb('threading'):
#     rf = RandomForestClassifier()
#     rf_grid = GridSearchCV(estimator=rf, param_grid=param_grid, verbose=10, n_jobs=-1)
#     rf_grid.fit(X_train, y_train)
# rf_grid.cv_results_
# rf_grid.best_estimator_

# %%
model_dict = {'rfc': RandomForestClassifier(n_estimators = 400, n_jobs = -1,max_features = 'sqrt'),
             'lm' : LogisticRegression(max_iter =10000,solver='sag',verbose = 10,n_jobs = -1,C = 1000),
             'gnb' : GaussianNB(),
             'mlp' : MLPClassifier(verbose = 10),
             'gbc' : GradientBoostingClassifier(n_estimators =  1000, max_leaf_nodes = 4,\
                                                max_depth = None ,min_samples_split = 5, verbose = 10,
                                               learning_rate = .1)}

# %%
def make_model(mdl_key,X_train,y_train,X_test):
    """Uses key from model_dict and trains it on X_train, y_train, then returns \
    the model object used and predicted values on X_test"""
    assert (mdl_key in model_dict.keys()),"Model tag not in model_dict keys!"
    mdl = model_dict[mdl_key]
    mdl.fit(X_train,y_train)
    predicted = mdl.predict(X_test)
    return mdl, predicted

# %%
rfc = 0
lm = 0
gnb = 0
mlp = 0
gbc = 0

# %%
# rfc, gnb_predicted = make_model('rfc',X_train,y_train,X_test)

# %%
# lm, predicted = make_model('lm',X_train_standard,y_train,X_test_standard)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# convergence after 1154 epochs took 273 seconds
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:
# Iteration 174, loss = 0.37245314
# Iteration 175, loss = 0.37308945
# Iteration 176, loss = 0.37262667
# Iteration 177, loss = 0.37276367
# Iteration 178, loss = 0.37267794
# Iteration 179, loss = 0.37224239
# Iteration 180, loss = 0.37204336
# Iteration 181, loss = 0.37223982
# Iteration 182, loss = 0.37262215
# Iteration 183, loss = 0.37201124
# Iteration 184, loss = 0.37238170
# Iteration 185, loss = 0.37211588
# Iteration 186, loss = 0.37189040
# Iteration 187, loss = 0.37207122
# Iteration 188, loss = 0.37250083
# Iteration 189, loss = 0.37221911
# Iteration 190, loss = 0.37135160
# Iteration 191, loss = 0.37179465
# Iteration 192, loss = 0.37144068
# Iteration 193, loss = 0.37182600
# Iteration 194, loss = 0.37144202
# Iteration 195, loss = 0.37162038
# Iteration 196, loss = 0.37129288
# Iteration 197, loss = 0.37137758
# Iteration 198, loss = 0.37147674
# Iteration 199, loss = 0.37151885
# Iteration 200, loss = 0.37127096
# /anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
gbc, gbc_predicted = make_model('gbc',X_train,y_train,X_test)
# Out:
#       Iter       Train Loss   Remaining Time
#          1           0.9351           29.84m
#          2           0.9254           28.08m
#          3           0.9172           27.29m
#          4           0.9107           26.98m
#          5           0.9052           26.75m
#          6           0.9000           26.95m
#          7           0.8960           28.18m
#          8           0.8922           29.30m
#          9           0.8893           29.67m
#         10           0.8866           29.64m
#         11           0.8841           29.83m
#         12           0.8820           29.57m
#         13           0.8805           29.41m
#         14           0.8789           29.16m
#         15           0.8775           29.10m
#         16           0.8761           28.76m
#         17           0.8750           28.57m
#         18           0.8739           28.37m
#         19           0.8729           28.28m
#         20           0.8719           28.10m
#         21           0.8710           27.99m
#         22           0.8703           27.87m
#         23           0.8696           27.75m
#         24           0.8689           27.59m
#         25           0.8681           27.56m
#         26           0.8674           27.54m
#         27           0.8668           27.44m
#         28           0.8663           27.36m
#         29           0.8657           27.27m
#         30           0.8653           27.10m
#         31           0.8649           27.06m
#         32           0.8645           26.98m
#         33           0.8639           26.99m
#         34           0.8636           27.04m
#         35           0.8632           27.02m
#         36           0.8628           26.95m
#         37           0.8624           26.93m
#         38           0.8621           26.93m
#         39           0.8617           26.96m
#         40           0.8614           26.97m
#         41           0.8611           26.90m
#         42           0.8608           26.84m
#         43           0.8605           26.77m
#         44           0.8602           26.72m
#         45           0.8599           26.70m
#         46           0.8596           26.63m
#         47           0.8592           26.67m
#         48           0.8590           26.62m
#         49           0.8588           26.62m
#         50           0.8586           26.58m
#         51           0.8584           26.54m
#         52           0.8581           26.55m
#         53           0.8579           26.53m
#         54           0.8578           26.44m
#         55           0.8576           26.44m
#         56           0.8574           26.41m
#         57           0.8572           26.44m
#         58           0.8571           26.41m
#         59           0.8568           26.49m
#         60           0.8567           26.51m
#         61           0.8566           26.47m
#         62           0.8564           26.55m
#         63           0.8563           26.58m
#         64           0.8561           26.64m
#         65           0.8560           26.73m
#         66           0.8559           26.72m
#         67           0.8558           26.77m
#         68           0.8556           26.72m
#         69           0.8555           26.66m
#         70           0.8554           26.67m
#         71           0.8552           26.62m
#         72           0.8551           26.55m
#         73           0.8550           26.55m
#        736           0.8315            5.89m
#        737           0.8315            5.87m
#        738           0.8314            5.85m
#        739           0.8314            5.83m
#        740           0.8314            5.81m
#        741           0.8313            5.78m
#        742           0.8313            5.76m
#        743           0.8313            5.73m
#        744           0.8313            5.71m
#        745           0.8313            5.69m
#        746           0.8312            5.66m
#        747           0.8312            5.64m
#        748           0.8312            5.62m
#        749           0.8312            5.59m
#        750           0.8311            5.57m
#        751           0.8311            5.55m
#        752           0.8311            5.53m
#        753           0.8311            5.50m
#        754           0.8310            5.48m
#        755           0.8310            5.46m
#        756           0.8310            5.43m
#        757           0.8310            5.41m
#        758           0.8309            5.39m
#        759           0.8309            5.37m
#        760           0.8309            5.35m
#        761           0.8309            5.32m
#        762           0.8308            5.30m
#        763           0.8308            5.28m
#        764           0.8308            5.25m
#        765           0.8307            5.23m
#        766           0.8307            5.20m
#        767           0.8307            5.18m
#        768           0.8307            5.16m
#        769           0.8307            5.14m
#        770           0.8306            5.11m
#        771           0.8306            5.09m
#        772           0.8306            5.06m
#        773           0.8306            5.04m
#        774           0.8306            5.02m
#        775           0.8305            4.99m
#        776           0.8305            4.97m
#        777           0.8305            4.95m
#        778           0.8305            4.92m
#        779           0.8305            4.90m
#        780           0.8304            4.88m
#        781           0.8304            4.86m
#        782           0.8304            4.83m
#        783           0.8304            4.81m
#        784           0.8304            4.78m
#        785           0.8303            4.76m
#        786           0.8303            4.74m
#        787           0.8303            4.71m
#        788           0.8303            4.69m
#        789           0.8303            4.67m
#        790           0.8302            4.65m
#        791           0.8302            4.62m
#        792           0.8302            4.60m
#        793           0.8302            4.58m
#        794           0.8302            4.56m
#        795           0.8301            4.53m
#        796           0.8301            4.51m
#        797           0.8301            4.49m
#        798           0.8301            4.47m
#        799           0.8300            4.44m
#        800           0.8300            4.42m
#        801           0.8300            4.40m
#        802           0.8300            4.37m
#        803           0.8300            4.35m
#        804           0.8299            4.33m
#        805           0.8299            4.30m
#        806           0.8299            4.28m
#        807           0.8299            4.26m
#        808           0.8298            4.24m
#        809           0.8298            4.21m
#        810           0.8298            4.19m
#        811           0.8298            4.17m
#        812           0.8297            4.15m
#        813           0.8297            4.13m
#        814           0.8297            4.10m
#        815           0.8297            4.08m
#        816           0.8296            4.06m
#        817           0.8296            4.04m
#        818           0.8296            4.01m
#        819           0.8296            3.99m
#        820           0.8296            3.97m
#        821           0.8295            3.95m
#        822           0.8295            3.92m
#        823           0.8295            3.90m
#        824           0.8295            3.88m
#        825           0.8294            3.85m
#        826           0.8294            3.83m
#        827           0.8294            3.81m
#        828           0.8294            3.79m
#        829           0.8293            3.77m
#        830           0.8293            3.74m
#        831           0.8293            3.72m
#        832           0.8292            3.70m
#        833           0.8292            3.68m
#        834           0.8292            3.65m
#        835           0.8292            3.63m
#        836           0.8292            3.61m
#        837           0.8291            3.58m
#        838           0.8291            3.56m
#        839           0.8291            3.54m
#        840           0.8291            3.52m
#        841           0.8291            3.49m
#        842           0.8290            3.47m
#        843           0.8290            3.45m
#        844           0.8290            3.42m
#        845           0.8290            3.40m
#        956           0.8264           57.95s
#        957           0.8264           56.62s
#        958           0.8264           55.31s
#        959           0.8264           54.00s
#        960           0.8264           52.66s
#        961           0.8264           51.33s
#        962           0.8263           50.00s
#        963           0.8263           48.69s
#        964           0.8263           47.38s
#        965           0.8263           46.06s
#        966           0.8262           44.75s
#        967           0.8262           43.43s
#        968           0.8262           42.10s
#        969           0.8262           40.80s
#        970           0.8261           39.49s
#        971           0.8261           38.17s
#        972           0.8261           36.84s
#        973           0.8261           35.53s
#        974           0.8261           34.20s
#        975           0.8260           32.88s
#        976           0.8260           31.56s
#        977           0.8260           30.25s
#        978           0.8260           28.93s
#        979           0.8260           27.61s
#        980           0.8259           26.29s
#        981           0.8259           24.98s
#        982           0.8259           23.67s
#        983           0.8259           22.35s
#        984           0.8259           21.03s
#        985           0.8258           19.72s
#        986           0.8258           18.40s
#        987           0.8258           17.09s
#        988           0.8258           15.77s
#        989           0.8258           14.46s
#        990           0.8257           13.14s
#        991           0.8257           11.83s
#        992           0.8257           10.51s
#        993           0.8257            9.19s
#        994           0.8257            7.88s
#        995           0.8256            6.56s
#        996           0.8256            5.25s
#        997           0.8256            3.94s
#        998           0.8256            2.62s
#        999           0.8256            1.31s
#       1000           0.8255            0.00s

# %%
# Fit random forest to basic model (sub_grade only)
rfc_b = RandomForestClassifier()
rfc_b.fit(Xb_train,yb_train)
predicted_b = rfc_b.predict(Xb_test)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
def make_confusion_matrix(model, threshold=.5, plot = False):
    # Predict class 1 if probability of being in class 1 is greater than threshold
    # (model.predict(X_test) does this automatically with a threshold of 0.5)
    y_predict = (model.predict_proba(X_test)[:, 1] >= threshold)
    mat_confusion = confusion_matrix(y_test, y_predict)

    if plot:
        plt.figure(dpi=80)
        plt.figure(figsize=(8, 8))
        sns.heatmap(mat_confusion, cmap=plt.cm.Blues, annot=True, square=True, fmt='d',
               xticklabels=['Paid off', 'Defaulted'],
               yticklabels=['Paid off', 'Defaulted']);
        plt.xlabel('prediction')
        plt.ylabel('actual')
        plt.title(str(type(model)))
    return mat_confusion
cm = pd.DataFrame(confusion_matrix(y_test, predicted))
make_confusion_matrix(rfc,.2105,plot = True)
make_confusion_matrix(gbc,.21, plot = True)[1][0]
# Out:
# 3117

# %% [markdown]
# # Models to display

# %%
all_models = [rfc,lm,gnb,mlp, gbc]
models = [ele for ele in all_models if ele]

# %%
# models to pickle
model_filepath = './models/'
dump(gbc,model_filepath + 'gbc.pkl', compress = True)
dump(mlp,model_filepath + 'mlp.pkl', compress = True)

dump(lm, model_filepath + 'lm.pkl', compress = True)
# Out:
# ['./models/lm.pkl']

# %%
# dump(rfc,model_filepath + 'rfc.pkl', compress = ('lzma', 9))
# Out:
# ['./models/rfc.pkl']

# %%
#models=[rfc,lm,gnb,mlp, gbc]
plt.figure(figsize=(15, 12))
fpr_b,tpr_b,thresholds = roc_curve(yb_test, rfc_b.predict_proba(Xb_test)[:,1])

plt.plot(fpr_b,tpr_b,lw=2, label = 'RFC on only sub_grade' +\
        ', AUC: ' + str(roc_auc_score(yb_test, rfc_b.predict_proba(Xb_test)[:,1]))[:6])
def plot_models():
    ''' Plots all models in the models list defined above. Also plots a dotted line\
    representing the curve of a random model.'''
    model_info=list()
    for model in models:
        fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(X_test)[:,1])
        auc_score = roc_auc_score(y_test, model.predict_proba(X_test)[:,1])
        f1 = f1_score(y_test,model.predict(X_test))
        model_info.append((model, auc_score,f1))
        plt.plot(fpr, tpr,lw=2, label = str(model)[:str(model).find('(')] + ', AUC: ' + str(auc_score)[:6])
    
    #Random guess line
    plt.plot([0,1],[0,1],c='violet',ls='--')
    plt.xlim([-0.05,1.05])
    plt.ylim([-0.05,1.05])
    plt.legend(loc='upper left')
    
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('ROC Scores For Various Models Predicting Defaulting Loans');
    return model_info
test = plot_models()

# %% [markdown]
# # Write a COST FUNCTION
# (Loans classified as defaulted but fully paid off * average paid off loan amount ) -
# (loans classified as paid off but defaulted * average loss to defaulted loan amount)

# %%
df = pd.read_pickle('./data/loan_data_2014.zip',compression = 'zip')
df = df.loc[(df['loan_status'] == 'Fully Paid') | (df['loan_status'] == 'Charged Off')]
df.shape
# Out:
# (223102, 145)

# %%
df_gain = df.loc[df['loan_status'] == 'Fully Paid']
df_gain
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 1       NaN        NaN    15000.0      15000.0          15000.0   60 months
# 2       NaN        NaN     9600.0       9600.0           9600.0   36 months
# 5       NaN        NaN    21425.0      21425.0          21425.0   60 months
# 6       NaN        NaN    17000.0      17000.0          17000.0   36 months
# 8       NaN        NaN     2500.0       2500.0           2500.0   36 months
# 10      NaN        NaN     5250.0       5250.0           5250.0   36 months
# 11      NaN        NaN    16000.0      16000.0          16000.0   60 months
# 14      NaN        NaN     2000.0       2000.0           2000.0   36 months
# 15      NaN        NaN     6000.0       6000.0           6000.0   36 months
# 16      NaN        NaN     3000.0       3000.0           3000.0   36 months
# 17      NaN        NaN     2000.0       2000.0           2000.0   36 months
# 18      NaN        NaN     4000.0       4000.0           4000.0   36 months
# 19      NaN        NaN    28000.0      28000.0          28000.0   60 months
# 20      NaN        NaN     2000.0       2000.0           2000.0   36 months
# 21      NaN        NaN     2000.0       2000.0           2000.0   36 months
# 22      NaN        NaN    14000.0      14000.0          14000.0   36 months
# 26      NaN        NaN     7200.0       7200.0           7200.0   36 months
# 27      NaN        NaN    18000.0      18000.0          18000.0   36 months
# 28      NaN        NaN     1000.0       1000.0           1000.0   36 months
# 29      NaN        NaN    10800.0      10800.0          10800.0   36 months
# 31      NaN        NaN     6000.0       6000.0           6000.0   36 months
# 32      NaN        NaN     8000.0       8000.0           8000.0   36 months
# 34      NaN        NaN     8750.0       8750.0           8750.0   36 months
# 35      NaN        NaN    21000.0      21000.0          21000.0   60 months
# 36      NaN        NaN     9000.0       9000.0           9000.0   36 months
# 37      NaN        NaN    21000.0      21000.0          21000.0   36 months
# 40      NaN        NaN    10000.0      10000.0          10000.0   36 months
# 41      NaN        NaN     6000.0       6000.0           6000.0   36 months
# 42      NaN        NaN     3625.0       3625.0           3625.0   36 months
# 43      NaN        NaN     1000.0       1000.0           1000.0   36 months
# ...     ...        ...        ...          ...              ...         ...
# 235592   16.99%       155.96     D        D1
# 235593    9.67%       385.35     B        B1
# 235594   10.99%       327.34     B        B2
# 235596   14.98%        69.32     C        C3
# 235599   18.25%      1269.73     D        D3
# 235601   13.53%       434.56     B        B5
# 235602   15.61%       629.37     C        C4
# 235603   21.48%       910.13     E        E2
# 235604    9.67%       224.79     B        B1
# 235605   13.53%       488.88     B        B5
# 235606   16.24%       493.86     C        C5
# 235607   13.98%       820.04     C        C1
# 235608   17.57%       548.05     D        D2
# 235609    7.90%      1001.29     A        A4
# 235610    8.90%       381.04     A        A5
# 235611   12.85%       336.22     B        B4
# 235612   16.24%       423.31     C        C5
# 235613    7.90%       312.91     A        A4
# 235614   22.90%       372.77     E        E4
# 235615   22.40%       191.99     E        E3
# 235616   21.48%       327.89     E        E2
# 235617   10.99%       196.41     B        B2
# 235618   11.99%       332.10     B        B3
# 235620   15.61%       209.79     C        C4
# 235622   18.25%       362.78     D        D3
# 235623   13.53%       509.25     B        B5
# 235624   14.47%       432.64     C        C2
# 235626    7.90%        62.59     A        A4
# 235627   16.99%       514.34     D        D1
# 235628   19.20%       367.58     D        D3
#
#                                 emp_title emp_length home_ownership  \
# 1                              MANAGEMENT  10+ years           RENT
# 2                        Admin Specialist  10+ years           RENT
# 5         Programming Analysis Supervisor    6 years           RENT
# 6                          Deputy sheriff  10+ years       MORTGAGE
# 8                  Manufacturing Engineer   < 1 year       MORTGAGE
# 10                          Store Manager    2 years           RENT
# 11                Foreign Service Officer    6 years            OWN
# 14           Student Services Coordinator    7 years           RENT
# 15                      Assistant manager  10+ years       MORTGAGE
# 16                  Respiratory Therapist    9 years           RENT
# 17                practice plan associate    8 years           RENT
# 18                       Accounting clerk    9 years           RENT
# 19                   Humana Cares Manager    2 years       MORTGAGE
# 20                              Sales Rep    2 years           RENT
# 21                                    NaN        NaN           RENT
# 22                    first grade teacher  10+ years            OWN
# 26                 Director of Operations    5 years       MORTGAGE
# 27             Education Advising Manager    8 years            OWN
# 28                               Attorney    3 years            OWN
# 29                       Asset Protection    8 years       MORTGAGE
# 31                         office manager     1 year           RENT
# 32               Senior Logistics Analyst    3 years       MORTGAGE
# 34                     Weather forecaster    8 years       MORTGAGE
# 35                       Milk Lab Manager    6 years       MORTGAGE
# 36                       Psych Therapyst      1 year           RENT
# 37               Senior Software Engineer  10+ years            OWN
# 40                           911 Director  10+ years       MORTGAGE
# 41                  International Adviser    2 years           RENT
# 42                      Financial Advisor   < 1 year       MORTGAGE
# 43                              machinist  10+ years       MORTGAGE
# ...                                   ...        ...            ...
# 235592                                NaN        NaN           RENT
# 235593                          Bartender    8 years           RENT
# 235594                 Sr. ProjectManager   < 1 year           RENT
# 235596                                NaN        NaN           RENT
# 235599                                NaN    9 years       MORTGAGE
# 235601          Chief Information Officer  10+ years       MORTGAGE
# 235602                     security guard    4 years           RENT
# 235603                   VP of Operations  10+ years       MORTGAGE
# 235604                             Welder  10+ years           RENT
# 235605  President, CEO, CFO, VP, Director     1 year           RENT
# 235606                                NaN        NaN       MORTGAGE
# 235607                              C N A  10+ years           RENT
# 235608                          Installer  10+ years       MORTGAGE
# 235609                                NaN        NaN       MORTGAGE
# 235610                     banquet server    3 years       MORTGAGE
# 235611                                 RN    2 years           RENT
# 235612                           Engineer    3 years       MORTGAGE
# 235613                 Compliance Manager    9 years       MORTGAGE
# 235614                         Lead sales  10+ years           RENT
# 235615                Maintenance Manager    6 years           RENT
# 235616      Health Planning Administrator  10+ years       MORTGAGE
# 235617                                NaN        NaN       MORTGAGE
# 235618                         Accountant    8 years           RENT
# 235620                            manager    7 years           RENT
# 235622                          MecÃ¡nica  10+ years           RENT
# 235623             Director of Operations    4 years           RENT
# 235624                 Financial Advisor     4 years       MORTGAGE
# 235626               Server Engineer Lead    3 years            OWN
# 235627                             patrol    7 years       MORTGAGE
# 235628                                NaN  10+ years       MORTGAGE
#
#         annual_inc verification_status   issue_d loan_status pymnt_plan  url  \
# 1          78000.0     Source Verified  Dec-2014  Fully Paid          n  NaN
# 2          69000.0     Source Verified  Dec-2014  Fully Paid          n  NaN
# 5          63800.0     Source Verified  Dec-2014  Fully Paid          n  NaN
# 6          75000.0            Verified  Dec-2014  Fully Paid          n  NaN
# 8          89000.0     Source Verified  Dec-2014  Fully Paid          n  NaN
# 10         26000.0        Not Verified  Dec-2014  Fully Paid          n  NaN
# 11        109777.0            Verified  Dec-2014  Fully Paid          n  NaN
# 14         37000.0        Not Verified  Dec-2014  Fully Paid          n  NaN
# 15        120000.0        Not Verified  Dec-2014  Fully Paid          n  NaN
# 16         60000.0        Not Verified  Dec-2014  Fully Paid          n  NaN
# 17         32200.0        Not Verified  Dec-2014  Fully Paid          n  NaN
# 18         50000.0        Not Verified  Dec-2014  Fully Paid          n  NaN
# 19         67000.0     Source Verified  Dec-2014  Fully Paid          n  NaN
# 20         52000.0        Not Verified  Dec-2014  Fully Paid          n  NaN
# 21         21312.0            Verified  Dec-2014  Fully Paid          n  NaN
# 22         42000.0     Source Verified  Dec-2014  Fully Paid          n  NaN
# 26         84000.0     Source Verified  Dec-2014  Fully Paid          n  NaN
# 27         70000.0        Not Verified  Dec-2014  Fully Paid          n  NaN
# 28         60000.0     Source Verified  Dec-2014  Fully Paid          n  NaN
# 29         42000.0            Verified  Dec-2014  Fully Paid          n  NaN
# 31         20000.0        Not Verified  Dec-2014  Fully Paid          n  NaN
# 32         94000.0        Not Verified  Dec-2014  Fully Paid          n  NaN
# 34         81200.0            Verified  Dec-2014  Fully Paid          n  NaN
# 35         48500.0     Source Verified  Dec-2014  Fully Paid          n  NaN
# 36         32000.0        Not Verified  Dec-2014  Fully Paid          n  NaN
# 37        120000.0            Verified  Dec-2014  Fully Paid          n  NaN
# 40        117000.0     Source Verified  Dec-2014  Fully Paid          n  NaN
# 41         42000.0        Not Verified  Dec-2014  Fully Paid          n  NaN
# 42         75000.0        Not Verified  Dec-2014  Fully Paid          n  NaN
# 43         45000.0        Not Verified  Dec-2014  Fully Paid          n  NaN
# ...            ...                 ...       ...         ...        ...  ...
# 235592     72000.0            Verified  Jan-2014  Fully Paid          n  NaN
# 235592                                                NaN              moving
# 235593                                                NaN         credit_card
# 235594                                                NaN         credit_card
# 235596                                                NaN         credit_card
# 235599                                                NaN      small_business
# 235601                                                NaN               other
# 235602                                                NaN  debt_consolidation
# 235603                                                NaN  debt_consolidation
# 235604                                                NaN               other
# 235605    Borrower added on 12/12/13 > I seek to be de...  debt_consolidation
# 235606                                                NaN  debt_consolidation
# 235607                                                NaN         credit_card
# 235608    Borrower added on 12/11/13 > Pay off high in...  debt_consolidation
# 235609    Borrower added on 12/11/13 > A Diamond for a...      major_purchase
# 235610                                                NaN  debt_consolidation
# 235611                                                NaN  debt_consolidation
# 235612    Borrower added on 12/10/13 > Payoff credit c...         credit_card
# 235613                                                NaN  debt_consolidation
# 235614                                                NaN               other
# 235615                                                NaN               other
# 235616                                                NaN         credit_card
# 235617    Borrower added on 12/10/13 > all my loans in...         credit_card
# 235618    Borrower added on 12/10/13 > pay off higher ...         credit_card
# 235620                                                NaN         credit_card
# 235622                                                NaN            vacation
# 235623                                                NaN         credit_card
# 235624                                                NaN  debt_consolidation
# 235626                                                NaN         credit_card
# 235627    Borrower added on 12/06/13 > I am going to c...  debt_consolidation
# 235628    Borrower added on 12/04/13 > I will like a l...               other
#
#                                     title zip_code addr_state    dti  \
# 1                      Debt consolidation    235xx         VA  12.03
# 2                      Debt consolidation    077xx         NJ  25.81
# 5                 Credit card refinancing    658xx         MO  18.49
# 6                      Debt consolidation    144xx         NY  23.63
# 8                        Home improvement    554xx         MN  13.77
# 10                     Debt consolidation    208xx         MD  14.36
# 11                     Debt consolidation    201xx         VA  11.63
# 14                                  Other    852xx         AZ  16.19
# 15                       Home improvement    403xx         KY   6.87
# 16                       Medical expenses    926xx         CA   9.54
# 17                Credit card refinancing    112xx         NY  22.14
# 18                     Debt consolidation    114xx         NY  33.99
# 19                     Debt consolidation    336xx         FL  16.13
# 20                                  Other    329xx         FL   5.98
# 21                       Medical expenses    463xx         IN   5.46
# 22                Credit card refinancing    754xx         TX  35.68
# 26                     Debt consolidation    760xx         TX  18.79
# 27                     Debt consolidation    333xx         FL   9.11
# 28                                  Other    567xx         MN  18.38
# 29                     Debt consolidation    467xx         IN  18.89
# 31                     Debt consolidation    960xx         CA  14.99
# 32                     Debt consolidation    358xx         AL  22.33
# 34                  Moving and relocation    967xx         HI  29.38
# 35                     Debt consolidation    881xx         NM  12.99
# 36                     Debt consolidation    631xx         MO  23.78
# 37                     Debt consolidation    958xx         CA  19.21
# 40                     Debt consolidation    439xx         OH  25.65
# 41                     Debt consolidation    787xx         TX  11.03
# 42                     Debt consolidation    273xx         NC  17.71
# 43                                  Other    452xx         OH  29.55
# ...                                   ...      ...        ...    ...
# 235592                            Persoal    324xx         FL  27.52
# 235593                         LoanGetter    900xx         CA  17.21
# 235594            Credit card refinancing    900xx         CA  10.32
# 235596         credit card refinance loan    925xx         CA  29.92
# 235599                      Business Loan    618xx         IL  14.59
# 235601                             Loan 1    351xx         AL  21.55
# 235602                 Debt consolidation    333xx         FL  31.05
# 235603                       Lending Club    463xx         IN  12.98
# 235601                             NaN                           NaN
# 235602                             NaN                           NaN
# 235603                             NaN                           NaN
# 235604                             NaN                           NaN
# 235605                             NaN                           NaN
# 235606                             NaN                           NaN
# 235607                             NaN                           NaN
# 235608                             NaN                           NaN
# 235609                             NaN                           NaN
# 235610                             NaN                           NaN
# 235611                             NaN                           NaN
# 235612                             NaN                           NaN
# 235613                             NaN                           NaN
# 235614                             NaN                           NaN
# 235615                             NaN                           NaN
# 235616                             NaN                           NaN
# 235617                             NaN                           NaN
# 235618                             NaN                           NaN
# 235620                             NaN                           NaN
# 235622                             NaN                           NaN
# 235623                             NaN                           NaN
# 235624                             NaN                           NaN
# 235626                             NaN                           NaN
# 235627                             NaN                           NaN
# 235628                             NaN                           NaN
#
#        disbursement_method debt_settlement_flag debt_settlement_flag_date  \
# 1                     Cash                    N                       NaN
# 2                     Cash                    N                       NaN
# 5                     Cash                    N                       NaN
# 6                     Cash                    N                       NaN
# 8                     Cash                    N                       NaN
# 10                    Cash                    N                       NaN
# 11                    Cash                    N                       NaN
# 14                    Cash                    N                       NaN
# 15                    Cash                    N                       NaN
# 16                    Cash                    N                       NaN
# 17                    Cash                    N                       NaN
# 18                    Cash                    N                       NaN
# 19                    Cash                    N                       NaN
# 20                    Cash                    N                       NaN
# 21                    Cash                    N                       NaN
# 22                    Cash                    N                       NaN
# 26                    Cash                    N                       NaN
# 27                    Cash                    N                       NaN
# 28                    Cash                    N                       NaN
# 29                    Cash                    N                       NaN
# 31                    Cash                    N                       NaN
# 32                    Cash                    N                       NaN
# 34                    Cash                    N                       NaN
# 35                    Cash                    N                       NaN
# 36                    Cash                    N                       NaN
# 37                    Cash                    N                       NaN
# 40                    Cash                    N                       NaN
# 41                    Cash                    N                       NaN
# 42                    Cash                    N                       NaN
# 43                    Cash                    N                       NaN
# ...                    ...                  ...                       ...
# 235592                Cash                    N                       NaN
# 235593                Cash                    N                       NaN
# 235594                Cash                    N                       NaN
# 235596                Cash                    N                       NaN
# 235599                Cash                    N                       NaN
# 235601                Cash                    N                       NaN
# 235602                Cash                    N                       NaN
# 235603                Cash                    N                       NaN
# 235604                Cash                    N                       NaN
# 235605                Cash                    N                       NaN
# 235606                Cash                    N                       NaN
# 235607                Cash                    N                       NaN
# 235608                Cash                    N                       NaN
# 235609                Cash                    N                       NaN
# 235610                Cash                    N                       NaN
# 235611                Cash                    N                       NaN
# 235612                Cash                    N                       NaN
# 235613                Cash                    N                       NaN
# 235614                Cash                    N                       NaN
# 235615                Cash                    N                       NaN
# 235616                Cash                    N                       NaN
# 235617                Cash                    N                       NaN
# 235618                Cash                    N                       NaN
# 235620                Cash                    N                       NaN
# 235622                Cash                    N                       NaN
# 235623                Cash                    N                       NaN
# 235624                Cash                    N                       NaN
# 235626                Cash                    N                       NaN
# 235627                Cash                    N                       NaN
# 235628                Cash                    N                       NaN
#
#        settlement_status settlement_date  settlement_amount  \
# 1                    NaN             NaN                NaN
# 2                    NaN             NaN                NaN
# 5                    NaN             NaN                NaN
# 6                    NaN             NaN                NaN
# 8                    NaN             NaN                NaN
# 10                   NaN             NaN                NaN
# 11                   NaN             NaN                NaN
# 14                   NaN             NaN                NaN
# 15                   NaN             NaN                NaN
# 16                   NaN             NaN                NaN
# 17                   NaN             NaN                NaN
# 18                   NaN             NaN                NaN
# 19                   NaN             NaN                NaN
# 20                   NaN             NaN                NaN
# 21                   NaN             NaN                NaN
# 22                   NaN             NaN                NaN
# 26                   NaN             NaN                NaN
# 27                   NaN             NaN                NaN
# 28                   NaN             NaN                NaN
# 29                   NaN             NaN                NaN
# 31                   NaN             NaN                NaN
# 32                   NaN             NaN                NaN
# 34                   NaN             NaN                NaN
# 35                   NaN             NaN                NaN
# 36                   NaN             NaN                NaN
# 37                   NaN             NaN                NaN
# 40                   NaN             NaN                NaN
# 41                   NaN             NaN                NaN
# 42                   NaN             NaN                NaN
# 43                   NaN             NaN                NaN
# ...                  ...             ...                ...
# 235592               NaN             NaN                NaN
# 235593               NaN             NaN                NaN
# 235594               NaN             NaN                NaN
# 235596               NaN             NaN                NaN
# 235599               NaN             NaN                NaN
# 235601               NaN             NaN                NaN
# 235602               NaN             NaN                NaN
# 235603               NaN             NaN                NaN
# 235604               NaN             NaN                NaN
# 235605               NaN             NaN                NaN
# 235606               NaN             NaN                NaN
# 235607               NaN             NaN                NaN
# 235608               NaN             NaN                NaN
# 235609               NaN             NaN                NaN
# 235610               NaN             NaN                NaN
# 235611               NaN             NaN                NaN
# 235612               NaN             NaN                NaN
# 235613               NaN             NaN                NaN
# 235614               NaN             NaN                NaN
# 235615               NaN             NaN                NaN
# 235616               NaN             NaN                NaN
# 235617               NaN             NaN                NaN
# 235618               NaN             NaN                NaN
# 235620               NaN             NaN                NaN
# 235622               NaN             NaN                NaN
# 235623               NaN             NaN                NaN
# 235624               NaN             NaN                NaN
# 235626               NaN             NaN                NaN
# 235627               NaN             NaN                NaN
# 235628               NaN             NaN                NaN
#
#         settlement_percentage  settlement_term
# 1                         NaN              NaN
# 2                         NaN              NaN
# 5                         NaN              NaN
# 6                         NaN              NaN
# 8                         NaN              NaN
# 10                        NaN              NaN
# 11                        NaN              NaN
# 14                        NaN              NaN
# 15                        NaN              NaN
# 16                        NaN              NaN
# 17                        NaN              NaN
# 18                        NaN              NaN
# 19                        NaN              NaN
# 20                        NaN              NaN
# 21                        NaN              NaN
# 22                        NaN              NaN
# 26                        NaN              NaN
# 27                        NaN              NaN
# 28                        NaN              NaN
# 29                        NaN              NaN
# 31                        NaN              NaN
# 32                        NaN              NaN
# 34                        NaN              NaN
# 35                        NaN              NaN
# 36                        NaN              NaN
# 37                        NaN              NaN
# 40                        NaN              NaN
# 41                        NaN              NaN
# 42                        NaN              NaN
# 43                        NaN              NaN
# ...                       ...              ...
# 235592                    NaN              NaN
# 235593                    NaN              NaN
# 235594                    NaN              NaN
# 235596                    NaN              NaN
# 235599                    NaN              NaN
# 235601                    NaN              NaN
# 235602                    NaN              NaN
# 235603                    NaN              NaN
# 235604                    NaN              NaN
# 235605                    NaN              NaN
# 235606                    NaN              NaN
# 235607                    NaN              NaN
# 235608                    NaN              NaN
# 235609                    NaN              NaN
# 235610                    NaN              NaN
# 235611                    NaN              NaN
# 235612                    NaN              NaN
# 235613                    NaN              NaN
# 235614                    NaN              NaN
# 235615                    NaN              NaN
# 235616                    NaN              NaN
# 235617                    NaN              NaN
# 235618                    NaN              NaN
# 235620                    NaN              NaN
# 235622                    NaN              NaN
# 235623                    NaN              NaN
# 235624                    NaN              NaN
# 235626                    NaN              NaN
# 235627                    NaN              NaN
# 235628                    NaN              NaN
#
# [181941 rows x 145 columns]

# %% [markdown]
# # Find Average gains and losses on misclassified loans

# %%
# Find average gains per successful loan
df_gain = df.loc[df['loan_status'] == 'Fully Paid']
df_gain = df_gain[['loan_amnt',
        'total_pymnt',
        'total_rec_int',
        'total_rec_late_fee',
        'total_rec_prncp','total_pymnt_inv']]
df_gain['total_gain'] = df_gain['total_rec_int'] + df_gain['total_rec_late_fee']
average_gain_per_successful_loan = df_gain['total_rec_int'].mean()

# %%
# Find average loss per charged off loan
df_loss=df.loc[df['loan_status'] == 'Charged Off']
df_loss = df[['loan_amnt',
    'total_rec_int',
    'total_rec_late_fee',
    'total_rec_prncp',
    'settlement_amount']]
df_loss['settlement_amount'].fillna(0,inplace = True)
df_loss['total_recovered'] = df_loss['total_rec_int'] +\
                                df_loss['total_rec_late_fee'] +\
                                df_loss['total_rec_late_fee'] + \
                                df_loss['total_rec_prncp'] + \
                                df_loss['settlement_amount']
df_loss['percent_recovered'] = df_loss['total_recovered'] / df_loss['loan_amnt']
average_loss_per_unsuccessful_loan = df_loss['total_recovered'].mean()
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]

# %% [markdown]
# # Test 1: Use F1_SCORE and for loop to find best threshold in rf model

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-133-f582edc75bc1> in <module>
# ----> 1 if(atwer):
#       2     print('test')
#
# NameError: name 'atwer' is not defined

# %%
def find_best_threshold(model, int_num_steps,X_test,y_test, metric):
    best_threshold = 0    
    if metric == 'f1':
        highest_f1 = 0
        for threshold in np.linspace (0, 1, int_num_steps):
            y_predict = (model.predict_proba(X_test)[:, 1] >= threshold) 
            f1 = f1_score(y_test,y_predict)
            if f1 > highest_f1:
                best_threshold, highest_f1 = threshold, f1
        return best_threshold, highest_f1;
    if metric == 'loan':
        lowest_cost = -1
        total_cost = -1
        make_confusion_matrix(model)
        best_false_positive = 0
        best_false_negative = 0
        for threshold in np.linspace(0,1, int_num_steps):
            # Positive in this case is classified as charged off
            false_positive = make_confusion_matrix(model,threshold)[0][1]
            false_negative = make_confusion_matrix(model,threshold)[1][0]
            total_cost = false_positive * average_gain_per_successful_loan + \
                            false_negative * average_loss_per_unsuccessful_loan
            if lowest_cost < 0:
                lowest_cost = total_cost
            elif total_cost < lowest_cost:
                lowest_cost = total_cost
                best_threshold = threshold
                print(lowest_cost)
        return best_threshold, lowest_cost

# %%
best_thresh, lowest_cost = find_best_threshold(gbc,20,X_test_standard,y_test, metric = 'loan')

# %%
make_confusion_matrix(gbc,best_thresh,plot = True)
print('Best Threshold: ', best_thresh)
# Out:
# Best Threshold:  0.15789473684210525

# %% [markdown]
# - Find a way to find money lost on defaulted loans

# %% [markdown]
# - stantard scalar
# - upscale?
